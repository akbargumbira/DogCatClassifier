# %%
import sys
sys.path.append('../')
from keras.preprocessing import image
from classifier import DogCatClassifier
# Out:
# Using TensorFlow backend.

# %%
# Create model
weights_path = '../model/sift_500/weights-best-0.78.hdf5'
model = DogCatClassifier(weights_path)

# %% [markdown]
# # Let's see on the test data

# %%
img1_path = '../test/img/1.jpg'
img1 = image.load_img(img1_path)
model.predict(img1_path, verbose=True)
img1
# Out:
# It is a dog!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=381x499 at 0x7F8EB714DC50>

# %%
img2_path = '../test/img/2.jpg'
img2 = image.load_img(img2_path)
model.predict(img2_path, verbose=True)
img2
# Out:
# It is a dog!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=296x299 at 0x7F8EB6E73B90>

# %%
img3_path = '../test/img/3.jpg'
img3 = image.load_img(img3_path)
model.predict(img3_path, verbose=True)
img3
# Out:
# It is a cat!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x299 at 0x7F8EB6E73C50>

# %%
img4_path = '../test/img/4.jpg'
img4 = image.load_img(img4_path)
model.predict(img4_path, verbose=True)
img4
# Out:
# It is a dog!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=374x288 at 0x7F8EB6E73CD0>

# %%
img5_path = '../test/img/5.jpg'
img5 = image.load_img(img5_path)
model.predict(img5_path, verbose=True)
img5
# Out:
# It is a dog!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x400 at 0x7F8EB6E73DD0>

# %%
img6_path = '../test/img/6.jpg'
img6 = image.load_img(img6_path)
model.predict(img6_path, verbose=True)
img6
# Out:
# It is a cat!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x375 at 0x7F8EB6E73D10>

# %%
img7_path = '../test/img/7.jpg'
img7 = image.load_img(img7_path)
model.predict(img7_path, verbose=True)
img7
# Out:
# It is a cat!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x148 at 0x7F8EB6E73210>

# %%
img8_path = '../test/img/8.jpg'
img8 = image.load_img(img8_path)
model.predict(img8_path, verbose=True)
img8
# Out:
# It is a cat!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=325x234 at 0x7F8EB6E73D50>

# %%
img9_path = '../test/img/9.jpg'
img9 = image.load_img(img9_path)
model.predict(img9_path, verbose=True)
img9
# Out:
# It is a cat!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x380 at 0x7F8EB78EE8D0>

# %%
img10_path = '../test/img/10.jpg'
img10 = image.load_img(img10_path)
model.predict(img10_path, verbose=True)
img10
# Out:
# It is a cat!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x374 at 0x7F8EB6E73F10>

# %%
img11_path = '../test/img/11.jpg'
img11 = image.load_img(img11_path)
model.predict(img11_path, verbose=True)
img11
# Out:
# It is a cat!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=278x370 at 0x7F8EB714D690>

# %%
tiger_path = '../test/img/tiger1.jpg'
tiger_img = image.load_img(tiger_path)
model.predict(tiger_path, verbose=True)
tiger_img
# Out:
# It is a cat!
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=304x166 at 0x7F8EB7131A90>
